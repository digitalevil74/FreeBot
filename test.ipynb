# %%
import requests, json

# %%
ACCESS_TOKEN = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjYTFhOTMxMjYxM2FmMWY3MDg5YTcyMTU0NWY1YjI4OCIsIm5iZiI6MTc2NzY2MTgzNy43NjMsInN1YiI6IjY5NWM2MTBkNGU5YTA2Y2MxNmRkMDRhNCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.TS-hafHMnzwqtEdPqrrS9UEkFb0JaUW3jWGGq6PIXM8"

# %%
url = "https://api.themoviedb.org/3/search/movie"
discover = "https://api.themoviedb.org/3/discover/movie"

# %%
headers = {
    "Authorization": f"Bearer {ACCESS_TOKEN}",
    "accept": "application/json"
}

params = {
    "query": "The Creator"
}

params_disc = {
    "primary_release_date.gte": "1980-01-01",
    "primary_release_date.lte": "1986-12-31",
#    "with_genres": "27",
    "sort_by": "vote_average.desc",
    "vote_count.gte": 300,
    "original_title": "Chronos"
    
}

# %%
response = requests.get(url, headers=headers, params=params)

print(response.status_code)
print(response.json())
# Out:
# 200
# ...

# %%
response = requests.get(discover, headers=headers, params=params_disc)

# %%
data = response.json()

# %%
print(data)
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/xlDUjb0Q5Dv6jPQRF5VE4IMjIy.jpg', 'genre_ids': [18, 80], 'id': 311, 'original_language': 'en', 'original_title': 'Once Upon a Time in America', 'overview': 'A former Prohibition-era Jewish gangster returns to the Lower East Side of Manhattan over thirty years later, where he once again must confront the ghosts and regrets of his old life.', 'popularity': 8.4321, 'poster_path': '/i0enkzsL5dPeneWnjl1fCWm6L7k.jpg', 'release_date': '1984-05-23', 'title': 'Once Upon a Time in America', 'video': False, 'vote_average': 8.4, 'vote_count': 5840}, {'adult': False, 'backdrop_path': '/ycBA7zK0v32oY4ohcK5dV3LjJbB.jpg', 'genre_ids': [12, 28, 878], 'id': 1891, 'original_language': 'en', 'original_title': 'The Empire Strikes Back', 'overview': 'The epic saga continues as Luke Skywalker, in hopes of defeating the evil Galactic Empire, learns the ways of the Jedi from aging master Yoda. But Darth Vader is more determined than ever to capture L
# ...

# %%
for n in data["results"]:
    print(n["release_date"], n["original_title"], n["vote_average"], n["vote_count"])
# Out:
# 2025-10-17 Frankenstein 7.704 2526
# 2024-02-22 파묘 7.5 608
# 2025-04-16 Sinners 7.5 3164
# 2025-05-28 Bring Her Back 7.394 1298
# 2025-08-04 Weapons 7.306 2656
# 2025-03-07 Den stygge stesøsteren 7.302 798
# 2024-08-13 Alien: Romulus 7.2 4179
# 2024-09-11 Speak No Evil 7.17 1868
# 2024-09-07 The Substance 7.143 5511
# 2025-07-30 Dracula 7.133 703
# 2024-03-19 Late Night with the Devil 7.11 1915
# 2025-05-14 Final Destination Bloodlines 7.096 2521
# 2025-07-28 Together 7.076 807
# 2024-10-31 Heretic 6.977 2361
# 2024-09-04 Beetlejuice Beetlejuice 6.956 2913
# 2025-09-03 The Conjuring: Last Rites 6.933 1539
# 2024-07-11 탈출: 프로젝트 사일런스 6.936 375
# 2025-09-10 The Long Walk 6.9 1001
# 2024-08-14 Strange Darling 6.926 800
# 2024-04-03 The First Omen 6.8 1220

# %%
genres = "https://api.themoviedb.org/3/genre/movie/list"
response = requests.get(genres, headers=headers)

print(response.status_code)
data = response.json()
print(data)
# Out:
# 200
# {'genres': [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}, {'id': 99, 'name': 'Documentary'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}, {'id': 36, 'name': 'History'}, {'id': 27, 'name': 'Horror'}, {'id': 10402, 'name': 'Music'}, {'id': 9648, 'name': 'Mystery'}, {'id': 10749, 'name': 'Romance'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 10770, 'name': 'TV Movie'}, {'id': 53, 'name': 'Thriller'}, {'id': 10752, 'name': 'War'}, {'id': 37, 'name': 'Western'}]}

# %%
for g in data["genres"]:
    print(g["id"], g["name"])
# Out:
# 28 Action
# 12 Adventure
# 16 Animation
# 35 Comedy
# 80 Crime
# 99 Documentary
# 18 Drama
# 10751 Family
# 14 Fantasy
# 36 History
# 27 Horror
# 10402 Music
# 9648 Mystery
# 10749 Romance
# 878 Science Fiction
# 10770 TV Movie
# 53 Thriller
# 10752 War
# 37 Western
